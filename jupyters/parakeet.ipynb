# %%
import nemo.collections.asr as nemo_asr
asr_model = nemo_asr.models.ASRModel.from_pretrained(model_name="nvidia/parakeet-tdt-1.1b")
# Out:
# [NeMo I 2025-06-03 17:21:06 nemo_logging:393] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo W 2025-06-03 17:21:07 nemo_logging:405] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 1
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     max_duration: 20
#     min_duration: 0.1
#     is_tarred: true
#     tarred_audio_filepaths: null
#     shuffle_n: 2048
#     bucketing_strategy: fully_randomized
#     bucketing_batch_size:
#     - 64
#     - 64
#     - 32
#     - 32
#     - 32
#     - 32
#     - 16
#     - 16
#     - 64
#     - 64
#     - 32
#     - 32
#     - 32
#     - 32
#     - 16
#     - 16
#     - 64
#     - 64
#     - 32
#     - 32
#     - 32
#     - 32
#     - 16
#     - 16
#     defer_setup: true
#
# ...

# %%
asr_model.tokenizer.vocab_size
# Out:
# 1024

# %%
output = asr_model.transcribe(['/tmp/librispeech/LibriSpeech/test-clean-processed/1995-1826-0010.wav'], timestamps=True)
# Out:
# [NeMo I 2025-05-31 19:53:32 nemo_logging:393] Timestamps requested, setting decoding timestamps to True. Capture them in Hypothesis object,                         with output[0][idx].timestep['word'/'segment'/'char']
# [NeMo I 2025-05-31 19:53:32 nemo_logging:393] Using RNNT Loss : tdt
#     Loss tdt_kwargs: {'fastemit_lambda': 0.0, 'clamp': -1.0, 'durations': [0, 1, 2, 3, 4], 'sigma': 0.02, 'omega': 0.1}
# [NeMo W 2025-05-31 19:53:32 nemo_logging:405] No conditional node support for Cuda.
#     Cuda graphs with while loops are disabled, decoding speed will be slower
#     Reason: No `cuda-python` module. Please do `pip install cuda-python>=12.3`
# Transcribing: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]

# %%
output[0]
# Out:
# Hypothesis(score=780.1188354492188, y_sequence=tensor([ 66, 821, 296, 104, 171, 839,  34, 250,  84, 841], device='cuda:0'), text='At any rate, I say go.', dec_out=None, dec_state=(tensor([[[ 8.1786e-05, -1.3396e-05,  6.7839e-07,  ...,  4.4554e-01,
#           -9.0769e-02,  6.8462e-05]],
#
#         [[ 1.1847e-02,  1.0968e-01, -7.3530e-02,  ...,  1.3952e-02,
#           -6.5562e-03, -9.9825e-02]]]), tensor([[[ 6.7872e-04, -9.2787e-01,  4.8145e-01,  ...,  9.9961e-01,
#           -9.1020e-02,  1.1774e-02]],
#
#         [[ 5.0909e-01,  1.7083e-01, -2.5300e-01,  ...,  5.9506e-02,
# ...
